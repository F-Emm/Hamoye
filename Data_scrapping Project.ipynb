# %% [markdown]
# <a href="https://colab.research.google.com/github/F-Emm/Hamoye/blob/master/Data_scrapping%20Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install beautifulsoup4

# %%
# !pip install requests

# %%
import sys
import time
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
try:
        
    page=requests.get('https://www.cricbuzz.com/')                            
    
except Exception as e:                                   
    error_type, error_obj, error_info = sys.exc_info()      
    print ('ERROR FOR LINK:',url)                          
    print (error_type, 'Line:', error_info.tb_lineno)     
                                                 
time.sleep(2)   
soup=BeautifulSoup(page.text,'html.parser')
links=soup.find_all('div',attrs={'class':'cb-nws-intr'})

# %%
page
# Out:
# <Response [200]>

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %% [markdown]
# ***The extraction of the summary text on each headline on this page***

# %%
for i in links:
  print(i.text)
  print("\n")
# Out:
# The team's impressive win in Rohit Sharma's first Test as captain conclusively captured where India is coming from, and where it wants to go
#
#
# The first double header will be played on March 27 while March 28 will mark the first appearance of IPL newcomers Gujarat Titans and Lucknow Super Giants
#
#
# The visitors have lost six wickets
#
#
# Due to persistent rain, the BAN-NZ fixture was shortened to 27-over-a-side
#
#
# He came, he saw, he bamboozled - no one did greater justice to the joy of living than the Australian legspinner, who mesmerised the cricketing world with his magic
#
#
# The 10-day camp has left some IPL franchises expressing their reservations mainly for lack of access to the players ahead of the season
#
#
# Hailing from one of India's poorest regions, Pooja Vastrakar's career rise has been an inspiration for many parents to let their daughters step out and play in Shahdol
#
#
# ...

# %% [markdown]
# **First text scrapping done**

# %%
#already done this first
from bs4 import BeautifulSoup
import requests

# %%
url = 'https://www.worldometers.info/gdp/gdp-by-country/'
load_web_page = requests.get(url)
soup_page_parser = BeautifulSoup(load_web_page.content, 'html.parser')
target_table = soup_page_parser.find("table",{"id":"example2"})
data_frame = pd.read_html(str(target_table))[0]

# %%
print(data_frame.tail(5))
# Out:
#        #           Country GDP (nominal, 2017) GDP (abbrev.) GDP growth  \
# 185  186        Micronesia        $336,427,500  $336 million      3.20%
# 186  187             Palau        $289,823,500  $290 million     -3.57%
# 187  188  Marshall Islands        $204,173,430  $204 million      3.60%
# 188  189          Kiribati        $185,572,502  $186 million      0.33%
# 189  190            Tuvalu         $39,731,317   $40 million      3.24%
#
#      Population (2017) GDP per capita Share of World GDP
# 185             532899           $631              0.00%
# 186              17808        $16,275              0.00%
# 187              58058         $3,517              0.00%
# 188             114158         $1,626              0.00%
# 189              11370         $3,494              0.00%

# %%
data_frame.to_excel("web_table_results.xlsx")
